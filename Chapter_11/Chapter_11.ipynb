# %%
list1 = [1,2,3]
list2 = [4,5]

tuple1 = list1,list2
print(tuple1)
# Out:
# ([1, 2, 3], [4, 5])

# %%
list1 = [1,2,3]
list2 = [4,5]

tuple1 = list1,list2
list2.append(6)
print(tuple1)
# Out:
# ([1, 2, 3], [4, 5, 6])

# %%
diccionario = {tuple1 : "Value"}
print(diccionario)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 diccionario = {tuple1 : "Value"}
#       2 print(diccionario)
#
# TypeError: cannot use 'tuple' as a dict key (unhashable type: 'list')
